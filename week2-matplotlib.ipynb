# %% [markdown]
# <a href="https://colab.research.google.com/github/aysenurkocaak/MachineLearningLab/blob/main/week2-matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pip install keras, numpy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Data

x= np.arange(0,10,0.1)
# [0, 0.1, 0.2 , 0.3 , .... 9.9]
y=np.sin(x)

#Graph creation

plt.plot(x,y)

#Determine chart properties

plt.title("Sinüs Grafigi")
plt.xlabel("X ekseni")
plt.ylabel("Y ekseni")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Data
x= np.random.rand(50)
y= np.random.rand(50)
colors = np.random.rand(50)
sizes= np.random.randint(50,1500,50)   #1500 degeri 150 olursa noktalar küçülür

plt.scatter(x,y, c=colors , s=sizes)

plt.title("Nokta Grafiği")
plt.xlabel(" X ekseni")
plt.ylabel("Y ekseni")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data= np.random.randn(1000)  #random.randn rastgele sayi üretir. bu dagilimin özelligi: ortalama=0 standart sapma=1 olmasidir.

plt.hist(data,bins=30)  #histogram grafigi yapcaz hist ile. bins=30 ise grafigimizde 30 cubuk olcak demek

plt.title("histogram")
plt.xlabel("Degerler")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=['A', 'B','C','D','E']
y=np.random.randint(1,10,5)

plt.bar(x,y)   #bar kullandık cünkü  sütun grafigi icin bu kullsnılır

plt.title("sütun grafigi")
plt.xlabel("Kategoriler")
plt.ylabel("Degerler")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
sizes= [30,25,15,10,5,5]

plt.pie(sizes)  #pie kullandık cünkü pasta grafigi yapcaz

plt.title("pasta grafigi")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

x = np.arange(-3, 3, 0.25)
y = np.arange(-3, 3, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.plot_surface(x, y, z)


ax.set_title("3D Graphics")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

# Show
plt.show()
